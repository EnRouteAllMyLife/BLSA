# %% [markdown]
# # Build Models

# %%
import os
import torch
import mlni
print(torch.__version__)
print(torch.backends.mps.is_available())
# Out:
# 2.9.0
# True

# %% [markdown]
# ## 1. LASSO

# %%
organ_list = ['eye', 'heart', 'endocrine', 'pulmonary', 'immune', 'hepatic', 'repro_male', 'repro_female', 'skin', 'renal', 'panceas', 'brain', 'digestive', 'salivary']

# %%
from mlni.adml_regression_lasso import regression_roi
for organ in organ_list:
    print(f"Processing organ: {organ}")
    folder_path = os.path.join('output', 'Lasso', organ)
    os.makedirs(folder_path, exist_ok=True)
    regression_roi(
        feature_tsv=f"data/training_data_{organ}.tsv",
        output_dir=f"output/Lasso/{organ}",
        cv_repetition=5,
        cv_strategy="hold_out",
        n_threads=8,
        seed=42,
        verbose=True)

# %% [markdown]
# ## 2. SVM

# %%
from mlni.adml_regression_rbf import regression_roi
for organ in organ_list:
    print(f"Processing organ: {organ}")
    folder_path = os.path.join('output', 'SVM', organ)
    os.makedirs(folder_path, exist_ok=True)
    regression_roi(
        feature_tsv=f"data/training_data_{organ}.tsv",
        output_dir=f"output/SVM/{organ}",
        cv_repetition=5,
        cv_strategy="hold_out",
        n_threads=8,
        seed=42,
        verbose=True)
# Out:
# Processing organ: eye
# MLNI for a regression with nested CV...
# Data split was performed based on validation strategy: hold_out...
#
# Data split has been done!
#
# Starts regression with SVR...
# Using custom gamma_range: [0.001, 0.005, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
# Using custom gamma_range: [0.001, 0.005, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
# 		[==========                                        ] 20.00%
# Repetition 0 of CV...
# 		[====================                              ] 40.00%
# Repetition 1 of CV...
# 		[==============================                    ] 60.00%
# Repetition 2 of CV...
# 		[========================================          ] 80.00%
# Repetition 3 of CV...
# 		[==================================================] 100.00%
# Repetition 4 of CV...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
#
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
#
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.001000...
# Inner CV for c=20.000000 and gamma=0.001000...
# Inner CV for c=40.000000 and gamma=0.001000...
# Inner CV for c=70.000000 and gamma=0.001000...
# Inner CV for c=100.000000 and gamma=0.001000...
# Inner CV for c=200.000000 and gamma=0.001000...
# Inner CV for c=400.000000 and gamma=0.001000...
# Inner CV for c=700.000000 and gamma=0.001000...
# Inner CV for c=1000.000000 and gamma=0.001000...
# Inner CV for c=2000.000000 and gamma=0.001000...
# Inner CV for c=4000.000000 and gamma=0.001000...
# Inner CV for c=7000.000000 and gamma=0.001000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.005000...Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
#
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.005000...
# Inner CV for c=20.000000 and gamma=0.005000...
# Inner CV for c=40.000000 and gamma=0.005000...
# Inner CV for c=70.000000 and gamma=0.005000...
# Inner CV for c=100.000000 and gamma=0.005000...
# Inner CV for c=200.000000 and gamma=0.005000...
# Inner CV for c=400.000000 and gamma=0.005000...
# Inner CV for c=700.000000 and gamma=0.005000...
# Inner CV for c=1000.000000 and gamma=0.005000...
# Inner CV for c=2000.000000 and gamma=0.005000...
# Inner CV for c=4000.000000 and gamma=0.005000...
# Inner CV for c=7000.000000 and gamma=0.005000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# Inner CV for c=10.000000 and gamma=0.010000...
# Inner CV for c=20.000000 and gamma=0.010000...
# Inner CV for c=40.000000 and gamma=0.010000...
# Inner CV for c=70.000000 and gamma=0.010000...
# Inner CV for c=100.000000 and gamma=0.010000...
# Inner CV for c=200.000000 and gamma=0.010000...
# Inner CV for c=400.000000 and gamma=0.010000...
# Inner CV for c=700.000000 and gamma=0.010000...
# Inner CV for c=1000.000000 and gamma=0.010000...
# Inner CV for c=2000.000000 and gamma=0.010000...
# Inner CV for c=4000.000000 and gamma=0.010000...
# Inner CV for c=7000.000000 and gamma=0.010000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# Inner CV for c=10.000000 and gamma=0.020000...
# Inner CV for c=20.000000 and gamma=0.020000...
# Inner CV for c=40.000000 and gamma=0.020000...
# Inner CV for c=70.000000 and gamma=0.020000...
# Inner CV for c=100.000000 and gamma=0.020000...
# Inner CV for c=200.000000 and gamma=0.020000...
# Inner CV for c=400.000000 and gamma=0.020000...
# Inner CV for c=700.000000 and gamma=0.020000...
# Inner CV for c=1000.000000 and gamma=0.020000...
# Inner CV for c=2000.000000 and gamma=0.020000...
# Inner CV for c=4000.000000 and gamma=0.020000...
# Inner CV for c=7000.000000 and gamma=0.020000...
# ...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=0.500000...
# Inner CV for c=20.000000 and gamma=0.500000...
# Inner CV for c=40.000000 and gamma=0.500000...
# Inner CV for c=70.000000 and gamma=0.500000...
# Inner CV for c=100.000000 and gamma=0.500000...
# Inner CV for c=200.000000 and gamma=0.500000...
# Inner CV for c=400.000000 and gamma=0.500000...
# Inner CV for c=700.000000 and gamma=0.500000...
# Inner CV for c=1000.000000 and gamma=0.500000...
# Inner CV for c=2000.000000 and gamma=0.500000...
# Inner CV for c=4000.000000 and gamma=0.500000...
# Inner CV for c=7000.000000 and gamma=0.500000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Inner CV for c=10.000000 and gamma=1.000000...
# Inner CV for c=20.000000 and gamma=1.000000...
# Inner CV for c=40.000000 and gamma=1.000000...
# Inner CV for c=70.000000 and gamma=1.000000...
# Inner CV for c=100.000000 and gamma=1.000000...
# Inner CV for c=200.000000 and gamma=1.000000...
# Inner CV for c=400.000000 and gamma=1.000000...
# Inner CV for c=700.000000 and gamma=1.000000...
# Inner CV for c=1000.000000 and gamma=1.000000...
# Inner CV for c=2000.000000 and gamma=1.000000...
# Inner CV for c=4000.000000 and gamma=1.000000...
# Inner CV for c=7000.000000 and gamma=1.000000...
# Mean results of the regression:
# Mean absolute error: 8.217871
# Finish...

# %% [markdown]
# ## 3. Elastic Net

# %%
from mlni.adml_regression_elastic import regression_roi
for organ in organ_list:
    print(f"Processing organ: {organ}")
    folder_path = os.path.join('output', 'EN', organ)
    os.makedirs(folder_path, exist_ok=True)
    regression_roi(
        feature_tsv=f"data/training_data_{organ}.tsv",
        output_dir=f"output/EN/{organ}",
        cv_repetition=5,
        cv_strategy="hold_out",
        n_threads=8,
        seed=42,
        verbose=True)
# Out:
# Processing organ: eye
# MLNI for a regression with nested CV...
# Data split was performed based on validation strategy: hold_out...
#
# Data split has been done!
#
# Starts regression with ElasticNet...
# 		[==========                                        ] 20.00%
# Repetition 0 of CV...
# 		[====================                              ] 40.00%
# Repetition 1 of CV...
# 		[==============================                    ] 60.00%
# Repetition 2 of CV...
# 		[========================================          ] 80.00%
# Repetition 3 of CV...
# 		[==================================================] 100.00%
# Repetition 4 of CV...
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# ...
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# Inner CV: alpha=1.0e-04, l1_ratio=0.10
# Inner CV: alpha=1.0e-04, l1_ratio=0.30
# Inner CV: alpha=1.0e-04, l1_ratio=0.50
# Inner CV: alpha=1.0e-04, l1_ratio=0.70
# Inner CV: alpha=1.0e-04, l1_ratio=0.90
# Inner CV: alpha=1.0e-03, l1_ratio=0.10
# Inner CV: alpha=1.0e-03, l1_ratio=0.30
# Inner CV: alpha=1.0e-03, l1_ratio=0.50
# Inner CV: alpha=1.0e-03, l1_ratio=0.70
# Inner CV: alpha=1.0e-03, l1_ratio=0.90
# Inner CV: alpha=1.0e-02, l1_ratio=0.10
# Inner CV: alpha=1.0e-02, l1_ratio=0.30
# Inner CV: alpha=1.0e-02, l1_ratio=0.50
# Inner CV: alpha=1.0e-02, l1_ratio=0.70
# Inner CV: alpha=1.0e-02, l1_ratio=0.90
# Inner CV: alpha=1.0e-01, l1_ratio=0.10
# Inner CV: alpha=1.0e-01, l1_ratio=0.30
# Inner CV: alpha=1.0e-01, l1_ratio=0.50
# Inner CV: alpha=1.0e-01, l1_ratio=0.70
# Inner CV: alpha=1.0e-01, l1_ratio=0.90
# Inner CV: alpha=1.0e+00, l1_ratio=0.10
# Inner CV: alpha=1.0e+00, l1_ratio=0.30
# Inner CV: alpha=1.0e+00, l1_ratio=0.50
# Inner CV: alpha=1.0e+00, l1_ratio=0.70
# Inner CV: alpha=1.0e+00, l1_ratio=0.90
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Mean results of the regression:
# Mean absolute error for the average model: 8.25515
# Mean absolute error for the single model: 8.245615
# Finish...
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/luchen/Library/Python/3.11/lib/python/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
